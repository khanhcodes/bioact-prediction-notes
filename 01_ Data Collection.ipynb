# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (0.10.7)
# Requirement already satisfied: easydict in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests>=2.18.4 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from chembl_webresource_client) (2.26.0)
# Requirement already satisfied: requests-cache~=0.7.0 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from chembl_webresource_client) (0.7.1)
# Requirement already satisfied: urllib3 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from chembl_webresource_client) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.2)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (5.4.1)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: six in c:\users\ngkha\anaconda3\envs\my-rdkit-env\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3         Torpedo californica
# 4                Mus musculus
# 5           Rattus norvegicus
# 6    Electrophorus electricus
# 7                  Bos taurus
# 8           Anopheles gambiae
# 9              Bemisia tabaci
# 10  Leptinotarsa decemlineata
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16        Plutella xylostella
# 17            Musca domestica
# 18  Pediculus humanus capitis
# 19          Spodoptera litura
# 20      Laodelphax striatella
# 21        Schizaphis graminum
# 22     Caenorhabditis elegans
# 23          Rattus norvegicus
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   27.0
# 1                        Cholinesterases; ACHE & BCHE   27.0
# 2                                Acetylcholinesterase   17.0
# 3                                Acetylcholinesterase   15.0
# 4                                Acetylcholinesterase   15.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                               AChE2   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16                               Acetylcholinesterase   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                             Acetylcholinesterase 1   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   13.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False       CHEMBL4780
# 4                False       CHEMBL3198
# 5                False       CHEMBL3199
# 6                False       CHEMBL4078
# 7                False       CHEMBL4768
# 8                False    CHEMBL2046266
# 9                False    CHEMBL2366409
# 10               False    CHEMBL2366490
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL3341583
# 23               False    CHEMBL2111475
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7787
# 4    10090
# 5    10116
# 6     8005
# 7     9913
# 8     7165
# 9     7038
# 10    7539
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    6239
# 23   10116

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7474             None     19468459                  []   CHEMBL4478126
# 7475             None     19468460                  []   CHEMBL4478126
# 7476             None     19487200                  []   CHEMBL4481753
# 7477             None     19487204                  []   CHEMBL4481753
# 7478             None     19487205                  []   CHEMBL4481753
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 7474  Inhibition of human erythrocyte AChE using ATC...          B
# 7475  Inhibition of human erythrocyte AChE using ATC...          B
# 7476  Inhibition of AChE (unknown origin) using acet...          B
# 7477  Inhibition of AChE (unknown origin) using acet...          B
# 7478  Inhibition of AChE (unknown origin) using acet...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000357
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 7474                    None                   None  BAO_0000190  BAO_0000357
# 7475                    None                   None  BAO_0000190  BAO_0000357
# 7476                    None                   None  BAO_0000190  BAO_0000357
# 7477                    None                   None  BAO_0000190  BAO_0000357
# 7478                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 7474  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7475  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7476  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7477  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7478  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type  units    uo_units upper_value value
# 0     None  IC50     uM  UO_0000065        None  0.75
# 1     None  IC50     uM  UO_0000065        None   0.1
# 2     None  IC50     uM  UO_0000065        None  50.0
# 3     None  IC50     uM  UO_0000065        None   0.3
# 4     None  IC50     uM  UO_0000065        None   0.8
# ...    ...   ...    ...         ...         ...   ...
# 7474  None  IC50     uM  UO_0000065        None  7.57
# 7475  None  IC50     uM  UO_0000065        None  10.0
# 7476  None  IC50     uM  UO_0000065        None   4.3
# 7477  None  IC50     uM  UO_0000065        None  15.5
# 7478  None  IC50     uM  UO_0000065        None  68.3
#
# [7479 rows x 45 columns]

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-10-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7474             None     19468459                  []   CHEMBL4478126
# 7475             None     19468460                  []   CHEMBL4478126
# 7476             None     19487200                  []   CHEMBL4481753
# 7477             None     19487204                  []   CHEMBL4481753
# 7478             None     19487205                  []   CHEMBL4481753
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 7474  Inhibition of human erythrocyte AChE using ATC...          B
# 7475  Inhibition of human erythrocyte AChE using ATC...          B
# 7476  Inhibition of AChE (unknown origin) using acet...          B
# 7477  Inhibition of AChE (unknown origin) using acet...          B
# 7478  Inhibition of AChE (unknown origin) using acet...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000357
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 7474                    None                   None  BAO_0000190  BAO_0000357
# 7475                    None                   None  BAO_0000190  BAO_0000357
# 7476                    None                   None  BAO_0000190  BAO_0000357
# 7477                    None                   None  BAO_0000190  BAO_0000357
# 7478                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 7474  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7475  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7476  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7477  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7478  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type  units    uo_units upper_value value
# 0     None  IC50     uM  UO_0000065        None  0.75
# 1     None  IC50     uM  UO_0000065        None   0.1
# 2     None  IC50     uM  UO_0000065        None  50.0
# 3     None  IC50     uM  UO_0000065        None   0.3
# 4     None  IC50     uM  UO_0000065        None   0.8
# ...    ...   ...    ...         ...         ...   ...
# 7474  None  IC50     uM  UO_0000065        None  7.57
# 7475  None  IC50     uM  UO_0000065        None  10.0
# 7476  None  IC50     uM  UO_0000065        None   4.3
# 7477  None  IC50     uM  UO_0000065        None  15.5
# 7478  None  IC50     uM  UO_0000065        None  68.3
#
# [6270 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 5043

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr #df2 not repeat
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7473             None     19468458                  []   CHEMBL4478126
# 7474             None     19468459                  []   CHEMBL4478126
# 7475             None     19468460                  []   CHEMBL4478126
# 7477             None     19487204                  []   CHEMBL4481753
# 7478             None     19487205                  []   CHEMBL4481753
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 7473  Inhibition of human erythrocyte AChE using ATC...          B
# 7474  Inhibition of human erythrocyte AChE using ATC...          B
# 7475  Inhibition of human erythrocyte AChE using ATC...          B
# 7477  Inhibition of AChE (unknown origin) using acet...          B
# 7478  Inhibition of AChE (unknown origin) using acet...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000357
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 7473                    None                   None  BAO_0000190  BAO_0000357
# 7474                    None                   None  BAO_0000190  BAO_0000357
# 7475                    None                   None  BAO_0000190  BAO_0000357
# 7477                    None                   None  BAO_0000190  BAO_0000357
# 7478                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 7473  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7474  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7475  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7477  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7478  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type  units    uo_units upper_value value
# 0     None  IC50     uM  UO_0000065        None  0.75
# 1     None  IC50     uM  UO_0000065        None   0.1
# 2     None  IC50     uM  UO_0000065        None  50.0
# 3     None  IC50     uM  UO_0000065        None   0.3
# 4     None  IC50     uM  UO_0000065        None   0.8
# ...    ...   ...    ...         ...         ...   ...
# 7473  None  IC50     uM  UO_0000065        None  10.0
# 7474  None  IC50     uM  UO_0000065        None  7.57
# 7475  None  IC50     uM  UO_0000065        None  10.0
# 7477  None  IC50     uM  UO_0000065        None  15.5
# 7478  None  IC50     uM  UO_0000065        None  68.3
#
# [5043 rows x 45 columns]

# %%
#Combine the molecule_chembl_id, canonical_smiles,  standard_value into a dataframe
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7473      CHEMBL4554172  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4cccc(F)c4)CC3)sc2-...
# 7474      CHEMBL4533844  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4ccccc4C(F)(F)F)CC3...
# 7475      CHEMBL4570655  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4ccccc4C)CC3)sc2-c2...
# 7477      CHEMBL4571704  COc1cc(O)c2c(c1)C1=C(c3c(O)c(O)cc(C)c3-c3cc(OC...
# 7478      CHEMBL4556664  COc1cc(O)c(C(C)=O)c(-c2c(C)cc(O)c3oc4c(O)cc(C)...
#
#      standard_value
# 0             750.0
# 1             100.0
# 2           50000.0
# 3             300.0
# 4             800.0
# ...             ...
# 7473        10000.0
# 7474         7570.0
# 7475        10000.0
# 7477        15500.0
# 7478        68300.0
#
# [5043 rows x 3 columns]

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %%
bioactivity_class = []
for i in df3.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append('inactive')
    elif float(i) <= 1000:
        bioactivity_class.append('active')
    else:
        bioactivity_class.append('intermediate')

# %%
df3.insert(2, 'class', bioactivity_class)

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7473      CHEMBL4554172  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4cccc(F)c4)CC3)sc2-...
# 7474      CHEMBL4533844  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4ccccc4C(F)(F)F)CC3...
# 7475      CHEMBL4570655  Cc1ccc(-c2nc(NC(=O)C3CCN(Cc4ccccc4C)CC3)sc2-c2...
# 7477      CHEMBL4571704  COc1cc(O)c2c(c1)C1=C(c3c(O)c(O)cc(C)c3-c3cc(OC...
# 7478      CHEMBL4556664  COc1cc(O)c(C(C)=O)c(-c2c(C)cc(O)c3oc4c(O)cc(C)...
#
#              class standard_value
# 0           active          750.0
# 1           active          100.0
# 2         inactive        50000.0
# 3           active          300.0
# 4           active          800.0
# ...            ...            ...
# 7473      inactive        10000.0
# 7474  intermediate         7570.0
# 7475      inactive        10000.0
# 7477      inactive        15500.0
# 7478      inactive        68300.0
#
# [5043 rows x 4 columns]

# %%
df3.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)
